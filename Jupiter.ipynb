# %%
import pandas as pd

# %%
import glob
import pandas as pd

files = glob.glob("data/*.csv")

df_list = [pd.read_csv(file) for file in files]

df = pd.concat(df_list, ignore_index=True)

df.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58    1.0  HARDERSFIELD   58.0  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60    1.0  HARDERSFIELD   60.0       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62    1.0  HARDERSFIELD   62.0     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63    1.0  HARDERSFIELD   63.0   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72    1.0  HARDERSFIELD   72.0         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate endDate  ...  Classification Volume  \
# 0  750mL     8.0  12.99  2024-01-01     NaN  ...             NaN    NaN
# 1  750mL     7.0  10.99  2024-01-01     NaN  ...             NaN    NaN
# 2  750mL     6.0  36.99  2024-01-01     NaN  ...             NaN    NaN
# 3  750mL     3.0  38.99  2024-01-01     NaN  ...             NaN    NaN
# 4  750mL     6.0  34.99  2024-01-01     NaN  ...             NaN    NaN
#
#    SalesQuantity SalesDollars SalesPrice SalesDate ExciseTax  VendorNo  \
# 0            NaN          NaN        NaN       NaN       NaN       NaN
# 1            NaN          NaN        NaN       NaN       NaN       NaN
# 2            NaN          NaN        NaN       NaN       NaN       NaN
# 3            NaN          NaN        NaN       NaN       NaN       NaN
# 4            NaN          NaN        NaN       NaN       NaN       NaN
#
#    Freight  Approval
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN
#
# [5 rows x 30 columns]

# %%
import os
from sqlalchemy import create_engine
engine=create_engine('postgresql:///inventory.db')

# %%
for file in os.listdir('data'):
    print(file)
# Out:
# .ipynb_checkpoints
# begin_inventory.csv
# end_inventory.csv
# purchases.csv
# purchase_prices.csv
# sales.csv
# vendor_invoice.csv

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15646659 entries, 0 to 15646658
# Data columns (total 30 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   InventoryId     str
#  1   Store           float64
#  2   City            str
#  3   Brand           float64
#  4   Description     str
#  5   Size            str
#  6   onHand          float64
#  7   Price           float64
#  8   startDate       str
#  9   endDate         str
#  10  VendorNumber    float64
#  11  VendorName      str
#  12  PONumber        float64
#  13  PODate          str
#  14  ReceivingDate   str
#  15  InvoiceDate     str
#  16  PayDate         str
#  17  PurchasePrice   float64
#  18  Quantity        float64
#  19  Dollars         float64
#  20  Classification  float64
#  21  Volume          object
#  22  SalesQuantity   float64
#  23  SalesDollars    float64
#  24  SalesPrice      float64
#  25  SalesDate       str
#  26  ExciseTax       float64
#  27  VendorNo        float64
#  28  Freight         float64
#  29  Approval        str
# dtypes: float64(16), object(1), str(13)
# memory usage: 3.5+ GB
